# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('trainMA.csv')
test = pd.read_csv('testMA.csv')

# %%
train = train.rename(columns={'Unnamed: 0': 'date_forecast'})
test = test.rename(columns={'Unnamed: 0': 'date_forecast'})

# %%
train.set_index('date_forecast', inplace=True)
test.set_index('date_forecast', inplace=True)
train.index = pd.to_datetime(train.index)
#test = test.drop(columns = ['date_calc'])

# %%
columns_only_in_df2 = train.columns.difference(test.columns)

# Visualizza le colonne uniche in ciascun DataFrame
print("Colonne presenti solo in df1:")
print(columns_only_in_df2)
# Out:
# Colonne presenti solo in df1:
# Index(['pv_measurement'], dtype='object')

# %%
import re
train = train.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
test = test.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
train['is_est'] = 0
train['is_est'].iloc[-4418:] = 1
# Out:
# C:\Users\claxl\AppData\Local\Temp\ipykernel_31260\2428353307.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['is_est'].iloc[-4418:] = 1

# %%
train['ceiling_height_aglm'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
nan_col = ['snow_densitykgm3','ceiling_height_aglm','cloud_base_aglm']
test['snow_densitykgm3'].fillna(0)
for col in nan_col:
    
    test[col] = test[col].fillna(0)
    train[col] = train[col].fillna(train[col].median())

train=train.dropna()
test=test.dropna()

# %%
train.columns
# Out:
# Index(['absolute_humidity_2mgm3', 'air_density_2mkgm3', 'ceiling_height_aglm',
#        'clear_sky_energy_1hJ', 'clear_sky_radW', 'cloud_base_aglm',
#        'dew_or_rimeidx', 'dew_point_2mK', 'diffuse_radW', 'diffuse_rad_1hJ',
#        'direct_radW', 'direct_rad_1hJ', 'effective_cloud_coverp', 'elevationm',
#        'fresh_snow_12hcm', 'fresh_snow_1hcm', 'fresh_snow_24hcm',
#        'fresh_snow_3hcm', 'fresh_snow_6hcm', 'is_dayidx', 'is_in_shadowidx',
#        'msl_pressurehPa', 'precip_5minmm', 'precip_type_5minidx',
#        'pressure_100mhPa', 'pressure_50mhPa', 'prob_rimep', 'rain_waterkgm2',
#        'relative_humidity_1000hPap', 'sfc_pressurehPa', 'snow_densitykgm3',
#        'snow_depthcm', 'snow_driftidx', 'snow_melt_10minmm', 'snow_waterkgm2',
#        'sun_azimuthd', 'sun_elevationd', 'super_cooled_liquid_waterkgm2',
#        't_1000hPaK', 'total_cloud_coverp', 'visibilitym', 'wind_speed_10mms',
#        'wind_speed_u_10mms', 'wind_speed_v_10mms', 'wind_speed_w_1000hPams',
#        'minute', 'hour', 'month', 'pv_measurement', 'is_est'],
#       dtype='object')

# %%
train.shape, test.shape
# Out:
# ((34061, 50), (720, 48))

# %%
train['pv_measurement'] = train['pv_measurement'].mask(train['is_in_shadowidx'] == 1, 0)

# %%
train['pv_measurement'].plot()
# Out:
# <Axes: xlabel='date_forecast'>

# %%
def transform(df):
    for col in df.columns:
        if col == 'pv_measurement':
            df['pv_measurement'] = np.sqrt(df['pv_measurement'])
            continue
        new_col_name = col + "_sqrt"
        df[new_col_name] = np.log10(df[col])

    return df

# %%
test.shape
# Out:
# (720, 48)

# %%
train = transform(train)
test = transform(test)

# %%
train.shape,test.shape
# Out:
# ((34061, 99), (720, 96))

# %%
train.index = pd.to_datetime(train.index)
test.index = pd.to_datetime(test.index)

# %%
def outlier_detect_ZScore(data, col, threshold=3):
    '''
    Outlier detection by Z-Score method. 
    Calculate the Z-score for each data point.
    Any value beyond:
        upper bound = mean + (Z-score * threshold * standard deviation)
        lower bound = mean - (Z-score * threshold * standard deviation)   
    are regarded as outliers. Default threshold is 3.
    
    Parameters:
    - data: The pandas DataFrame containing the data.
    - col: The name of the column in the DataFrame to perform outlier detection on.
    - threshold: The Z-score threshold for defining outliers. Default is 3.
    
    Returns:
    - outlier_index: A boolean Series indicating which rows are outliers.
    - para: Tuple containing the upper and lower bounds for outliers.
    '''
    mean = data[col].mean()
    std = data[col].std()
    Upper_fence = mean + (threshold * std)
    Lower_fence = mean - (threshold * std)
    para = (Lower_fence, Upper_fence)
    z_scores = (data[col] - mean) / std
    outlier_index = (z_scores > threshold) | (z_scores < -threshold)
    if outlier_index.any():
        num_outliers = outlier_index.value_counts()[True]
        print(f'Num of outliers detected: {num_outliers} in column {col}')
        percentage_of_outliers = (num_outliers / len(data)) * 100
        print(f'Percentage of outliers: {percentage_of_outliers:.2f}% relative to {len(data)} data points')
        print('————————————————————————————————————————————————————')
    return outlier_index, para
def remove_outliers_ZScore(data, col, threshold=3):
    outlier_index, _ = outlier_detect_ZScore(data, col, threshold)
    data_cleaned = data[~outlier_index]
    return data_cleaned

# %%
for col in train.columns:
    data_without_outliers = remove_outliers_ZScore(train, col, threshold=3)
# Out:
# Num of outliers detected: 92 in column absolute_humidity_2mgm3
# Percentage of outliers: 0.27% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 262 in column air_density_2mkgm3
# Percentage of outliers: 0.77% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 552 in column ceiling_height_aglm
# Percentage of outliers: 1.62% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 1019 in column cloud_base_aglm
# Percentage of outliers: 2.99% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 1210 in column dew_or_rimeidx
# Percentage of outliers: 3.55% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 69 in column dew_point_2mK
# Percentage of outliers: 0.20% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 571 in column diffuse_radW
# Percentage of outliers: 1.68% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 553 in column diffuse_rad_1hJ
# Percentage of outliers: 1.62% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 1133 in column direct_radW
# Percentage of outliers: 3.33% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 1137 in column direct_rad_1hJ
# Percentage of outliers: 3.34% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 576 in column fresh_snow_12hcm
# Percentage of outliers: 1.69% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 331 in column fresh_snow_1hcm
# Percentage of outliers: 0.97% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 778 in column fresh_snow_24hcm
# Percentage of outliers: 2.28% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 379 in column fresh_snow_3hcm
# Percentage of outliers: 1.11% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 441 in column fresh_snow_6hcm
# Percentage of outliers: 1.29% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 173 in column msl_pressurehPa
# Percentage of outliers: 0.51% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 589 in column precip_5minmm
# Percentage of outliers: 1.73% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 489 in column precip_type_5minidx
# Percentage of outliers: 1.44% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 174 in column pressure_100mhPa
# Percentage of outliers: 0.51% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 173 in column pressure_50mhPa
# Percentage of outliers: 0.51% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 251 in column prob_rimep
# Percentage of outliers: 0.74% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 752 in column rain_waterkgm2
# Percentage of outliers: 2.21% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 164 in column relative_humidity_1000hPap
# Percentage of outliers: 0.48% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 173 in column sfc_pressurehPa
# Percentage of outliers: 0.51% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 713 in column snow_depthcm
# Percentage of outliers: 2.09% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 121 in column snow_melt_10minmm
# Percentage of outliers: 0.36% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 716 in column snow_waterkgm2
# Percentage of outliers: 2.10% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 847 in column super_cooled_liquid_waterkgm2
# Percentage of outliers: 2.49% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 98 in column t_1000hPaK
# Percentage of outliers: 0.29% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 353 in column wind_speed_10mms
# Percentage of outliers: 1.04% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 93 in column wind_speed_u_10mms
# Percentage of outliers: 0.27% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 172 in column wind_speed_v_10mms
# Percentage of outliers: 0.50% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 5 in column wind_speed_w_1000hPams
# Percentage of outliers: 0.01% relative to 34061 data points
# ————————————————————————————————————————————————————
# Num of outliers detected: 1107 in column pv_measurement
# Percentage of outliers: 3.25% relative to 34061 data points
# ————————————————————————————————————————————————————

# %%
train['hours'] = train.index.hour
train['day'] = train.index.day
train['month'] = train.index.month
train['year'] = train.index.year
train['dayofyear'] = train.index.dayofyear

# %%
train['total_rad'] = train['direct_radW'] + train['diffuse_radW']/10
test['total_rad'] = test['direct_radW'] + test['diffuse_radW']/10

# %%
train['total*cloud'] = train['total_rad'] * train['effective_cloud_coverp']
test['total*cloud'] = test['total_rad'] * test['effective_cloud_coverp']

# %%
test['hours'] = test.index.hour
test['day'] = test.index.day
test['month'] = test.index.month
test['year'] = test.index.year
test['dayofyear'] = test.index.dayofyear

# %%
# Supponiamo che "gruppi" sia il risultato della suddivisione
gruppi = train.groupby('is_est')

# Itera attraverso i gruppi e crea un DataFrame separato per ciascun gruppo
dataframes_per_gruppo = {}
for valore, gruppo in gruppi:
    dataframes_per_gruppo[valore] = gruppo.copy()
train_set = dataframes_per_gruppo[0]
val_set = dataframes_per_gruppo[1]

# %%
train_set = train_set.drop(columns = ['is_est'])
val_set = val_set.drop(columns = ['is_est'])

# %%
train = train.drop(columns = ['is_est'])

# %%
from sklearn.metrics import mean_absolute_error
import lightgbm as lgb
def objective(trial):
    param = {
            'metric': 'mae', 
            'random_state': 42,
            'n_estimators': trial.suggest_int('n_estimators',10,1000),
            'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-3, 10.0),
            'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-3, 10.0),
            'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.3,0.4,0.5,0.6,0.7,0.8,0.9, 1.0]),
            'subsample': trial.suggest_categorical('subsample', [0.4,0.5,0.6,0.7,0.8,1.0]),
            'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4,1e-1),
            'max_depth': trial.suggest_int('max_depth', 1,50),
            'num_leaves' : trial.suggest_int('num_leaves', 1, 1000),
            'min_child_samples': trial.suggest_int('min_child_samples', 1, 300),
            'cat_smooth' : trial.suggest_int('min_data_per_groups', 1, 100),
            'verbosity': -1
        }
    model = lgb.LGBMRegressor(**param)

        # Extract target variable for training and testing data
    y_train = train_set['pv_measurement']
    y_val = val_set['pv_measurement']

        # Extract features for training and testing data
    X_train = train_set.drop(columns = 'pv_measurement')
    X_val = val_set.drop(columns = 'pv_measurement')
        
        # Train the XGBoost model
    model.fit(X_train, y_train,eval_set=[(X_val,y_val)])

        # Make predictions on the test data
    y_pred = model.predict(X_val)

        # Evaluate the model using Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_val, y_pred)
    return mae

# %%
import optuna
import warnings
warnings.filterwarnings("ignore")
from warnings import simplefilter
simplefilter("ignore", category=RuntimeWarning)
study = optuna.create_study(direction='minimize')
# Out:
# [I 2023-11-01 14:13:02,652] A new study created in memory with name: no-name-3f753fff-30a1-4d2d-be51-5be4d898afd3

# %%
study.optimize(objective, n_trials=50)
# Out:
# [I 2023-11-01 14:13:05,462] Trial 0 finished with value: 228.98033493219071 and parameters: {'n_estimators': 515, 'reg_alpha': 0.31939522724613967, 'reg_lambda': 0.5548955932816158, 'colsample_bytree': 0.9, 'subsample': 0.4, 'learning_rate': 0.0032716604651280515, 'max_depth': 33, 'num_leaves': 424, 'min_child_samples': 166, 'min_data_per_groups': 6}. Best is trial 0 with value: 228.98033493219071.
# [I 2023-11-01 14:13:06,527] Trial 1 finished with value: 716.5541886089146 and parameters: {'n_estimators': 353, 'reg_alpha': 0.008748483260918415, 'reg_lambda': 0.002790416419337623, 'colsample_bytree': 0.4, 'subsample': 0.4, 'learning_rate': 0.00013408401002534484, 'max_depth': 38, 'num_leaves': 110, 'min_child_samples': 264, 'min_data_per_groups': 42}. Best is trial 0 with value: 228.98033493219071.
# [I 2023-11-01 14:13:09,371] Trial 2 finished with value: 190.58560460387926 and parameters: {'n_estimators': 740, 'reg_alpha': 0.0010839032455204176, 'reg_lambda': 0.001396092015711602, 'colsample_bytree': 0.8, 'subsample': 0.5, 'learning_rate': 0.0028925002016363345, 'max_depth': 38, 'num_leaves': 499, 'min_child_samples': 232, 'min_data_per_groups': 1}. Best is trial 2 with value: 190.58560460387926.
# [I 2023-11-01 14:13:09,984] Trial 3 finished with value: 380.47646991173445 and parameters: {'n_estimators': 107, 'reg_alpha': 0.001134761095406944, 'reg_lambda': 0.2872952452394844, 'colsample_bytree': 0.7, 'subsample': 0.4, 'learning_rate': 0.00779691721593675, 'max_depth': 18, 'num_leaves': 387, 'min_child_samples': 125, 'min_data_per_groups': 6}. Best is trial 2 with value: 190.58560460387926.
# [I 2023-11-01 14:13:13,468] Trial 4 finished with value: 122.1843701863788 and parameters: {'n_estimators': 702, 'reg_alpha': 3.413944369758901, 'reg_lambda': 0.0168034941495209, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.04353351042148624, 'max_depth': 27, 'num_leaves': 876, 'min_child_samples': 187, 'min_data_per_groups': 87}. Best is trial 4 with value: 122.1843701863788.
# [I 2023-11-01 14:13:14,885] Trial 5 finished with value: 401.5555667074297 and parameters: {'n_estimators': 331, 'reg_alpha': 9.73565887471202, 'reg_lambda': 1.0560454001994168, 'colsample_bytree': 0.3, 'subsample': 0.6, 'learning_rate': 0.0023461304300552302, 'max_depth': 37, 'num_leaves': 110, 'min_child_samples': 37, 'min_data_per_groups': 41}. Best is trial 4 with value: 122.1843701863788.
# [I 2023-11-01 14:13:16,787] Trial 6 finished with value: 589.6297011569794 and parameters: {'n_estimators': 371, 'reg_alpha': 0.0016270702245592546, 'reg_lambda': 0.41649991222181115, 'colsample_bytree': 1.0, 'subsample': 1.0, 'learning_rate': 0.00073361725569042, 'max_depth': 33, 'num_leaves': 860, 'min_child_samples': 154, 'min_data_per_groups': 7}. Best is trial 4 with value: 122.1843701863788.
# [I 2023-11-01 14:13:17,671] Trial 7 finished with value: 123.65035935605333 and parameters: {'n_estimators': 393, 'reg_alpha': 0.0032167600457553617, 'reg_lambda': 0.012870180366486076, 'colsample_bytree': 0.7, 'subsample': 0.8, 'learning_rate': 0.03467679189844334, 'max_depth': 6, 'num_leaves': 335, 'min_child_samples': 243, 'min_data_per_groups': 75}. Best is trial 4 with value: 122.1843701863788.
# [I 2023-11-01 14:13:17,970] Trial 8 finished with value: 357.59604304700696 and parameters: {'n_estimators': 61, 'reg_alpha': 0.0031107228725328223, 'reg_lambda': 0.04495560213843815, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.015322104425946406, 'max_depth': 7, 'num_leaves': 59, 'min_child_samples': 175, 'min_data_per_groups': 67}. Best is trial 4 with value: 122.1843701863788.
# [I 2023-11-01 14:13:18,805] Trial 9 finished with value: 654.2877129545818 and parameters: {'n_estimators': 187, 'reg_alpha': 2.1565071606527444, 'reg_lambda': 0.006413745873899767, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.00080968541050878, 'max_depth': 32, 'num_leaves': 944, 'min_child_samples': 180, 'min_data_per_groups': 64}. Best is trial 4 with value: 122.1843701863788.
# [I 2023-11-01 14:13:25,823] Trial 10 finished with value: 125.55564155777738 and parameters: {'n_estimators': 911, 'reg_alpha': 0.1816313051040311, 'reg_lambda': 8.228408872681651, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.09991287989936422, 'max_depth': 47, 'num_leaves': 707, 'min_child_samples': 84, 'min_data_per_groups': 96}. Best is trial 4 with value: 122.1843701863788.
# [I 2023-11-01 14:13:26,454] Trial 11 finished with value: 179.82563538746777 and parameters: {'n_estimators': 627, 'reg_alpha': 0.013504713864272886, 'reg_lambda': 0.017494645562708497, 'colsample_bytree': 0.7, 'subsample': 0.8, 'learning_rate': 0.058820176321617436, 'max_depth': 1, 'num_leaves': 701, 'min_child_samples': 285, 'min_data_per_groups': 96}. Best is trial 4 with value: 122.1843701863788.
# [I 2023-11-01 14:13:29,665] Trial 12 finished with value: 122.22901554365434 and parameters: {'n_estimators': 819, 'reg_alpha': 0.04601589971571229, 'reg_lambda': 0.014936330220549836, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.024638085548112323, 'max_depth': 17, 'num_leaves': 279, 'min_child_samples': 222, 'min_data_per_groups': 77}. Best is trial 4 with value: 122.1843701863788.
# [I 2023-11-01 14:13:33,758] Trial 13 finished with value: 122.21492461786762 and parameters: {'n_estimators': 986, 'reg_alpha': 0.05018299530532286, 'reg_lambda': 0.029202185577810482, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.02029247499539653, 'max_depth': 21, 'num_leaves': 238, 'min_child_samples': 218, 'min_data_per_groups': 79}. Best is trial 4 with value: 122.1843701863788.
# [I 2023-11-01 14:13:38,106] Trial 14 finished with value: 132.24682622349346 and parameters: {'n_estimators': 1000, 'reg_alpha': 0.5676291601057721, 'reg_lambda': 0.08272565694165133, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.09470926754176298, 'max_depth': 23, 'num_leaves': 650, 'min_child_samples': 205, 'min_data_per_groups': 85}. Best is trial 4 with value: 122.1843701863788.
# [I 2023-11-01 14:13:41,974] Trial 15 finished with value: 118.24222722239298 and parameters: {'n_estimators': 712, 'reg_alpha': 0.06594251543408453, 'reg_lambda': 0.05466397812887566, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.014135504403392988, 'max_depth': 24, 'num_leaves': 236, 'min_child_samples': 99, 'min_data_per_groups': 55}. Best is trial 15 with value: 118.24222722239298.
# [I 2023-11-01 14:13:54,828] Trial 16 finished with value: 116.26264337220562 and parameters: {'n_estimators': 672, 'reg_alpha': 1.424698839263214, 'reg_lambda': 0.11054394055328327, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.011453236425635841, 'max_depth': 28, 'num_leaves': 605, 'min_child_samples': 5, 'min_data_per_groups': 26}. Best is trial 16 with value: 116.26264337220562.
# [I 2023-11-01 14:14:07,217] Trial 17 finished with value: 116.96031692629515 and parameters: {'n_estimators': 582, 'reg_alpha': 0.9313673227131275, 'reg_lambda': 0.08908810818089308, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.012127332044312853, 'max_depth': 45, 'num_leaves': 585, 'min_child_samples': 1, 'min_data_per_groups': 27}. Best is trial 16 with value: 116.26264337220562.
# [I 2023-11-01 14:14:16,936] Trial 18 finished with value: 121.94699590455 and parameters: {'n_estimators': 570, 'reg_alpha': 0.8669242411288702, 'reg_lambda': 0.15966372233228193, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.007837723465750306, 'max_depth': 48, 'num_leaves': 598, 'min_child_samples': 13, 'min_data_per_groups': 23}. Best is trial 16 with value: 116.26264337220562.
# [I 2023-11-01 14:14:20,625] Trial 19 finished with value: 126.16610705362145 and parameters: {'n_estimators': 459, 'reg_alpha': 1.1034728339177362, 'reg_lambda': 0.09967827595351622, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.008489379389297447, 'max_depth': 44, 'num_leaves': 544, 'min_child_samples': 55, 'min_data_per_groups': 26}. Best is trial 16 with value: 116.26264337220562.
# [I 2023-11-01 14:14:38,573] Trial 20 finished with value: 115.5151464035048 and parameters: {'n_estimators': 816, 'reg_alpha': 0.2500765197387097, 'reg_lambda': 0.13654996951890552, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.029778068387544248, 'max_depth': 41, 'num_leaves': 786, 'min_child_samples': 13, 'min_data_per_groups': 21}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:15:03,434] Trial 21 finished with value: 117.43213210759806 and parameters: {'n_estimators': 829, 'reg_alpha': 0.25317943737823256, 'reg_lambda': 0.19412690239069522, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.03544844078430165, 'max_depth': 42, 'num_leaves': 750, 'min_child_samples': 1, 'min_data_per_groups': 22}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:15:09,839] Trial 22 finished with value: 115.55214544019309 and parameters: {'n_estimators': 648, 'reg_alpha': 0.5148758174567388, 'reg_lambda': 0.12061235848090746, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.013238645658159536, 'max_depth': 50, 'num_leaves': 804, 'min_child_samples': 42, 'min_data_per_groups': 32}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:15:17,000] Trial 23 finished with value: 118.100298053621 and parameters: {'n_estimators': 816, 'reg_alpha': 0.1538855627052647, 'reg_lambda': 0.16465751976917567, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.02414592691489709, 'max_depth': 50, 'num_leaves': 782, 'min_child_samples': 53, 'min_data_per_groups': 35}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:15:25,557] Trial 24 finished with value: 117.76651843819735 and parameters: {'n_estimators': 652, 'reg_alpha': 0.3985844853507995, 'reg_lambda': 0.044034180969989525, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.057174458626161766, 'max_depth': 42, 'num_leaves': 972, 'min_child_samples': 31, 'min_data_per_groups': 15}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:15:33,431] Trial 25 finished with value: 117.78908345792962 and parameters: {'n_estimators': 893, 'reg_alpha': 0.15063538696603593, 'reg_lambda': 1.0325182163639903, 'colsample_bytree': 0.9, 'subsample': 0.5, 'learning_rate': 0.005550165976856511, 'max_depth': 30, 'num_leaves': 816, 'min_child_samples': 76, 'min_data_per_groups': 35}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:15:37,980] Trial 26 finished with value: 118.37964867578681 and parameters: {'n_estimators': 781, 'reg_alpha': 0.5282431657202216, 'reg_lambda': 0.1653549384423926, 'colsample_bytree': 0.3, 'subsample': 1.0, 'learning_rate': 0.021510589256354528, 'max_depth': 50, 'num_leaves': 672, 'min_child_samples': 114, 'min_data_per_groups': 16}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:15:47,220] Trial 27 finished with value: 119.42714630010688 and parameters: {'n_estimators': 638, 'reg_alpha': 1.7228800082949427, 'reg_lambda': 0.049867320474802246, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.012362478758994929, 'max_depth': 40, 'num_leaves': 901, 'min_child_samples': 30, 'min_data_per_groups': 44}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:15:51,138] Trial 28 finished with value: 170.56887408098078 and parameters: {'n_estimators': 483, 'reg_alpha': 0.10663499979629268, 'reg_lambda': 0.36052556230597527, 'colsample_bytree': 0.8, 'subsample': 0.7, 'learning_rate': 0.004831691627111476, 'max_depth': 36, 'num_leaves': 482, 'min_child_samples': 60, 'min_data_per_groups': 51}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:15:55,359] Trial 29 finished with value: 116.80663775417453 and parameters: {'n_estimators': 541, 'reg_alpha': 0.33720528645852177, 'reg_lambda': 0.6966995907974384, 'colsample_bytree': 0.4, 'subsample': 0.7, 'learning_rate': 0.035005048951679885, 'max_depth': 16, 'num_leaves': 758, 'min_child_samples': 23, 'min_data_per_groups': 34}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:16:00,627] Trial 30 finished with value: 120.09682273778563 and parameters: {'n_estimators': 897, 'reg_alpha': 0.2962804649370215, 'reg_lambda': 0.24911759865496194, 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.017674564662065465, 'max_depth': 29, 'num_leaves': 617, 'min_child_samples': 129, 'min_data_per_groups': 13}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:16:03,499] Trial 31 finished with value: 117.02415234636689 and parameters: {'n_estimators': 550, 'reg_alpha': 0.3303793536261565, 'reg_lambda': 0.5867247963098823, 'colsample_bytree': 0.4, 'subsample': 0.7, 'learning_rate': 0.02964338678661942, 'max_depth': 10, 'num_leaves': 811, 'min_child_samples': 22, 'min_data_per_groups': 33}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:16:06,948] Trial 32 finished with value: 118.68963461397429 and parameters: {'n_estimators': 687, 'reg_alpha': 0.5342467322489488, 'reg_lambda': 0.7933725003025743, 'colsample_bytree': 0.4, 'subsample': 0.4, 'learning_rate': 0.04588359707232812, 'max_depth': 14, 'num_leaves': 731, 'min_child_samples': 44, 'min_data_per_groups': 33}. Best is trial 20 with value: 115.5151464035048.
# [I 2023-11-01 14:16:10,325] Trial 33 finished with value: 121.37501688761735 and parameters: {'n_estimators': 752, 'reg_alpha': 0.24649579927913373, 'reg_lambda': 1.8335049077111536, 'colsample_bytree': 0.4, 'subsample': 0.7, 'learning_rate': 0.03193251628695633, 'max_depth': 13, 'num_leaves': 996, 'min_child_samples': 73, 'min_data_per_groups': 44}. Best is trial 20 with value: 115.5151464035048.

# %%
trial = study.best_trial

print("  Value: {}".format(trial.value))
print(trial.params)
# Out:
#   Value: 115.81848737581655
# {'n_estimators': 842, 'reg_alpha': 8.681807852841986, 'reg_lambda': 0.002557234797105677, 'colsample_bytree': 0.9, 'subsample': 0.4, 'learning_rate': 0.008096649443129583, 'max_depth': 42, 'num_leaves': 833, 'min_child_samples': 43, 'min_data_per_groups': 54}

# %%
param = {'n_estimators': 582, 'reg_alpha': 0.012273002852168912, 'reg_lambda': 0.02415509792144517, 'colsample_bytree': 0.4, 'subsample': 0.6, 'learning_rate': 0.02045834457600994, 'max_depth': 14, 'num_leaves': 129, 'min_child_samples': 18, 'min_data_per_groups': 77}

# %%
model_A = lgb.LGBMRegressor(**trial.params)

# %%
X_train = train.drop(columns = 'pv_measurement')
y_train = train['pv_measurement']

# %%
pd.set_option('display.max_columns', 184)

test.shape,train.shape
# Out:
# ((720, 56), (34061, 55))

# %%
model_A.fit(X_train,y_train)
y_pred_A = model_A.predict(test)
# Out:
# [LightGBM] [Warning] Unknown parameter: min_data_per_groups
# [LightGBM] [Warning] Unknown parameter: min_data_per_groups
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002971 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8325
# [LightGBM] [Info] Number of data points in the train set: 34061, number of used features: 49
# [LightGBM] [Info] Start training from score 629.398666
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[252], line 2
#       1 model_A.fit(X_train,y_train)
# ----> 2 y_pred_A = model_A.predict(test)
#
# File ~\anaconda3\Lib\site-packages\lightgbm\sklearn.py:894, in LGBMModel.predict(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, validate_features, **kwargs)
#     892 n_features = X.shape[1]
#     893 if self._n_features != n_features:
# --> 894     raise ValueError("Number of features of the model must "
#     895                      f"match the input. Model n_features_ is {self._n_features} and "
#     896                      f"input n_features is {n_features}")
#     897 # retrive original params that possibly can be used in both training and prediction
#     898 # and then overwrite them (considering aliases) with params that were passed directly in prediction
#     899 predict_params = self._process_params(stage="predict")
#
# ValueError: Number of features of the model must match the input. Model n_features_ is 54 and input n_features is 56

# %%
plt.plot(range(len(y_pred_A)), (y_pred_A), label='Predizione', color='red', linestyle='-')
# Aggiungi una legenda
plt.legend()

# Aggiungi etichette agli assi
plt.ylabel('Valori y')

# Titolo del grafico
plt.title('Grafico di Predizione')

# Mostra il grafico
plt.show()

# %%
df = pd.DataFrame({'Prediction':y_pred_A})

# %%
test = test.reset_index()
df.loc[test['is_in_shadowidx'] == 1, 'Prediction'] = 0

# %%
df.to_csv('A4.csv')

# %%
df
# Out:
#      Prediction
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3     38.301533
# 4    386.605650
# ..          ...
# 715  242.821103
# 716   69.667864
# 717    0.000000
# 718    0.000000
# 719    0.000000
#
# [720 rows x 1 columns]

# %%
train.columns
# Out:
# Index(['absolute_humidity_2mgm3', 'air_density_2mkgm3', 'ceiling_height_aglm',
#        'clear_sky_energy_1hJ', 'clear_sky_radW', 'cloud_base_aglm',
#        'dew_or_rimeidx', 'dew_point_2mK', 'diffuse_radW', 'diffuse_rad_1hJ',
#        'direct_radW', 'direct_rad_1hJ', 'effective_cloud_coverp', 'elevationm',
#        'fresh_snow_12hcm', 'fresh_snow_1hcm', 'fresh_snow_24hcm',
#        'fresh_snow_3hcm', 'fresh_snow_6hcm', 'is_dayidx', 'is_in_shadowidx',
#        'msl_pressurehPa', 'precip_5minmm', 'precip_type_5minidx',
#        'pressure_100mhPa', 'pressure_50mhPa', 'prob_rimep', 'rain_waterkgm2',
#        'relative_humidity_1000hPap', 'sfc_pressurehPa', 'snow_densitykgm3',
#        'snow_depthcm', 'snow_driftidx', 'snow_melt_10minmm', 'snow_waterkgm2',
#        'sun_azimuthd', 'sun_elevationd', 'super_cooled_liquid_waterkgm2',
#        't_1000hPaK', 'total_cloud_coverp', 'visibilitym', 'wind_speed_10mms',
#        'wind_speed_u_10mms', 'wind_speed_v_10mms', 'wind_speed_w_1000hPams',
#        'minute', 'hour', 'month', 'pv_measurement', 'hours', 'day', 'year',
#        'dayofyear', 'total_rad', 'total*cloud'],
#       dtype='object')

# %%
import seaborn as sns

# Crea un DataFrame con le due feature
data = pd.DataFrame({'clear_sky_radW': train['effective_cloud_coverp'], 'direct_radW': train['total_rad']})

# Genera il pairplot con solo le due feature
sns.set(style="ticks")
sns.pairplot(data, kind="scatter")
plt.show()

# %%
data['mod'] = (data['clear_sky_radW']/80)*data['direct_radW']

# %%
plt.plot(range(len(train['pv_measurement'])), (train['pv_measurement']),  color='g', label='target')
plt.plot(range(len(train['total*cloud'])), (train['total*cloud']/10),  color='b', label='mod')

# Aggiungi etichette agli assi
plt.xlabel('Indice')
plt.ylabel('Valore della Variabile')

# Aggiungi una legenda se necessario
plt.legend()

# Mostra lo scatter plot
plt.show()

# %%
# Out:
# <Axes: xlabel='date_forecast'>
