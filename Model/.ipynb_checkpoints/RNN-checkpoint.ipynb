# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
base = "/Users/claxl/Documents/GitHub/MLProject/Data Exploration/EDA/clearData/"

# %%
df_train_est_A = pd.read_csv(base + "A/train_est_A.csv")
df_train_obs_A = pd.read_csv(base + "A/train_obs_A.csv")
df_train_est_B = pd.read_csv(base + "B/train_est_B.csv")
df_train_obs_B = pd.read_csv(base + "B/train_obs_B.csv")
df_train_est_C = pd.read_csv(base + "C/train_est_C.csv")
df_train_obs_C = pd.read_csv(base + "C/train_obs_C.csv")
df_test_A = pd.read_csv(base + "C/X_test_C.csv")

# %%
df_train_est_A=df_train_est_A.drop(columns = "Unnamed: 0")
df_train_obs_A=df_train_obs_A.drop(columns = "Unnamed: 0")
df_train_A = pd.concat([df_train_est_A, df_train_obs_A])
df_train_A['Location'] = 'A'

# %%
df_train_est_B=df_train_est_B.drop(columns = "Unnamed: 0")
df_train_obs_B=df_train_obs_B.drop(columns = "Unnamed: 0")
df_train_B = pd.concat([df_train_est_B, df_train_obs_B])
df_train_B['Location'] = 'B'

# %%
df_train_est_C=df_train_est_C.drop(columns = "Unnamed: 0")
df_train_obs_C=df_train_obs_C.drop(columns = "Unnamed: 0")
df_train_C = pd.concat([df_train_est_C, df_train_obs_C])
df_train_C['Location'] = 'C'

# %%
df_train_C.tail()
# Out:
#        absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# 29195                       5.9                1.249                2284.9
# 29196                       5.8                1.250                1257.8
# 29197                       5.4                1.253                1317.3
# 29198                       5.2                1.255                6466.2
# 29199                       4.9                1.257                2652.0
#
#        clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# 29195               998763.3            211.1             761.5
# 29196               536014.3             91.1             862.1
# 29197               174610.0             16.5            1019.2
# 29198                12626.0              0.0            3165.1
# 29199                    0.0              0.0            1536.5
#
#        dew_or_rime:idx  dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  ...  \
# ...

# %%
df_train = pd.concat([df_train_A,df_train_B])
df_train = pd.concat([df_train, df_train_C])
df_train = df_train.reset_index()
df_train
# Out:
#        index  absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# 0          0                       8.4                1.233
# 1          1                       8.2                1.233
# 2          2                       8.2                1.230
# 3          3                       8.1                1.229
# 4          4                       8.3                1.228
# ...      ...                       ...                  ...
# 99009  29195                       5.9                1.249
# 99010  29196                       5.8                1.250
# 99011  29197                       5.4                1.253
# 99012  29198                       5.2                1.255
# 99013  29199                       4.9                1.257
#
#        ceiling_height_agl:m  clear_sky_energy_1h:J  clear_sky_rad:W  \
# 0                    1425.1                    0.0              0.0
# 1                    4068.2                    0.0              0.0
# ...

# %%
features_no_loc = df_test_A.drop(columns='date_forecast').columns
features_no_loc
# Out:
# Index(['absolute_humidity_2m:gm3', 'air_density_2m:kgm3',
#        'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W',
#        'cloud_base_agl:m', 'dew_or_rime:idx', 'dew_point_2m:K',
#        'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J',
#        'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm',
#        'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm',
#        'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx',
#        'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx',
#        'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p',
#        'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa',
#        'snow_density:kgm3', 'snow_depth:cm', 'snow_drift:idx',
#        'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d',
#        'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K',
#        'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms',
# ...

# %%
# Calcola il primo e terzo quartile per ciascuna colonna
Q1 = df_test_A[features_no_loc].quantile(0.25)
Q3 = df_test_A[features_no_loc].quantile(0.75)

    # Calcola l'intervallo interquartile (IQR) per ciascuna colonna
IQR = Q3 - Q1

    # Definisci i limiti per identificare gli outlier per ciascuna colonna
limite_inferiore = Q1 - 3 * IQR
limite_superiore = Q3 + 3 * IQR

    # Sostituisci gli outlier con i valori più estremi tra i non-outlier per ciascuna colonna
for colonna in df_test_A[features_no_loc].columns:
    df_test_A[colonna] = df_test_A[colonna].apply(lambda x: limite_inferiore[colonna] if x < limite_inferiore[colonna] else (limite_superiore[colonna] if x > limite_superiore[colonna] else x))

# %%
filter = ["direct_rad:W", "clear_sky_rad:W" , "diffuse_rad:W","is_in_shadow:idx", "relative_humidity_1000hPa:p"]

# %%
df_test_clean = df_test_A[filter]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaled_X_train_v1 = scaler.fit_transform(df_test_clean)
scaled_X_test = pd.DataFrame(df_test_clean,columns=df_test_clean.columns,index=df_test_clean.index)

# %%
df_train_clean['pv_measurement'] = df_train['pv_measurement']
df_train_clean
# Out:
#      direct_rad:W  clear_sky_rad:W  diffuse_rad:W  is_in_shadow:idx  \
# 0           0.000            0.000          0.000               0.0
# 1           0.000            0.000          0.000               0.0
# 2           0.000            0.000          0.000               0.0
# 3           2.100           11.675          9.375               0.0
# 4          25.450           76.875         47.400               0.0
# ..            ...              ...            ...               ...
# 715        13.425           85.100         33.625               0.0
# 716         3.550           24.800         14.325               0.0
# 717         0.000            1.275          1.300               0.0
# 718         0.000            0.000          0.000               0.0
# 719         0.000            0.000          0.000               0.0
#
#      relative_humidity_1000hPa:p  pv_measurement
# 0                         80.275             0.0
# 1                         79.825             0.0
# ...

# %%
def create_sequences(data, target_column, window_size):
    sequences = []
    targets = []
    for i in range(len(data) - window_size):
        sequences.append(data[i:i+window_size].drop(columns=[target_column]).values)
        targets.append(data.iloc[i+window_size][target_column])
    return np.array(sequences), np.array(targets)

# %%
# Assuming `your_dataframe` is your DataFrame
X,Y = create_sequences(df_train_clean,'pv_measurement',5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 2
#       1 # Assuming `your_dataframe` is your DataFrame
# ----> 2 X,Y = create_sequences(df_train_clean,'pv_measurement',5)
#
# Cell In[48], line 5, in create_sequences(data, target_column, window_size)
#       3 targets = []
#       4 for i in range(len(data) - window_size):
# ----> 5     sequences.append(data[i:i+window_size].drop(columns=[target_column]).values)
#       6     targets.append(data.iloc[i+window_size][target_column])
#       7 return np.array(sequences), np.array(targets)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)
X_train.shape, y_train.shape
# Out:
# ((79207, 5, 5), (79207,))

# %%
def create_sequences(df):
    sequences = []
    sequence_length = 24  # You want sequences of length 24

    # Padding the start of the DataFrame with (sequence_length-1) copies of the first row
    padded_df = pd.concat([pd.DataFrame([df.iloc[0]] * (sequence_length-1), columns=df.columns), df], ignore_index=True)

    # Now, every row in the original DataFrame will be the end of a 24-row sequence in the result
    for end_idx in range(sequence_length-1, len(padded_df)):
        sequences.append(padded_df.iloc[end_idx-sequence_length+1:end_idx+1].values)

    return np.array(sequences)  # Returning a NumPy array of shape (720, 24, 5)

# Assuming `your_dataframe` is your DataFrame
sequences = create_sequences(scaled_X_test)

# %%
predictions = [model.predict(np.array([seq])) for seq in sequences]
# Out:
# ...
# 1/1 [==============================] - 0s 15ms/step

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import SimpleRNN, Dense

# Crea il modello RNN
model = keras.Sequential()
model.add(SimpleRNN(50,activation='tanh', input_shape=(X.shape[1], X.shape[2])))


model.add(Dense(1))

model.compile(loss='mae', optimizer='adam')

# Addestra il modello
model.fit(X_train, y_train, epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 2476/2476 [==============================] - 4s 1ms/step - loss: 116.2113
# Epoch 2/15
# 2476/2476 [==============================] - 3s 1ms/step - loss: 104.5317
# Epoch 3/15
# 2476/2476 [==============================] - 3s 1ms/step - loss: 96.3133
# Epoch 4/15
# 2476/2476 [==============================] - 3s 1ms/step - loss: 90.7169
# Epoch 5/15
# 2476/2476 [==============================] - 3s 1ms/step - loss: 87.0123
# Epoch 6/15
# 2476/2476 [==============================] - 3s 1ms/step - loss: 84.2434
# Epoch 7/15
# 2476/2476 [==============================] - 4s 1ms/step - loss: 81.9196
# Epoch 8/15
# 2476/2476 [==============================] - 3s 1ms/step - loss: 80.1657
# Epoch 9/15
# 2476/2476 [==============================] - 3s 1ms/step - loss: 78.7287
# Epoch 10/15
# 2476/2476 [==============================] - 3s 1ms/step - loss: 77.4170
# Epoch 11/15
# 2476/2476 [==============================] - 3s 1ms/step - loss: 76.3014
# Epoch 12/15
# ...

# %%
y_pred = model.predict(sequences)
# Out:
# 23/23 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)

print(f"Errore assoluto medio (MAE): {mae}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[119], line 2
#       1 from sklearn.metrics import mean_absolute_error
# ----> 2 mae = mean_absolute_error(y_test, y_pred)
#       4 print(f"Errore assoluto medio (MAE): {mae}")
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
# ...

# %%
import matplotlib.pyplot as plt


# Crea un array con gli indici delle osservazioni
indices = range(720)  # Assumiamo che y_pred e y_test abbiano la stessa lunghezza

# Crea un plot per y_pred
plt.figure(figsize=(20, 20))
plt.plot(indices, np.array(predictions).flatten(), label='Previsioni', marker='o', linestyle='-')

# Crea un plot per y_test
#plt.plot(indices, y_test, label='Valori di test', marker='x', linestyle='--')

plt.xlabel('Indice Osservazione')
plt.ylabel('Valore')
plt.title('Plot delle Previsioni e Valori di Test')
plt.legend()
plt.grid(True)

# Mostra il plot
plt.show()

# %%
predictions_a = predictions

# %%
predictions_b = predictions

# %%
predictions_c = predictions

# %%
all_preds = np.array(predictions_a).flatten().tolist() + np.array(predictions_b).flatten().tolist()  + np.array(predictions_c).flatten().tolist()

# %%
dict_preds = {'id' : [i for i in range(2160)],  'prediction' : all_preds  } #'time' : hourly_date_range, 'location' : location_list
send_in_df = pd.DataFrame(dict_preds)
send_in_df.set_index('id', inplace=True)
send_in_df
# Out:
#       prediction
# id
# 0      65.062164
# 1      65.417488
# 2      66.599266
# 3     142.765747
# 4     278.665375
# ...          ...
# 2155   21.521236
# 2156    0.026008
# 2157    0.021591
# 2158   -0.017138
# 2159   -0.019808
#
# [2160 rows x 1 columns]

# %%
send_in_df.to_csv("rnn.csv")
