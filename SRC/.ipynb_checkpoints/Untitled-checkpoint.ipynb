# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('trainM.csv')
test = pd.read_csv('testM.csv')

# %%
train = train.rename(columns={'Unnamed: 0': 'date_forecast'})

# %%
train.set_index('date_forecast', inplace=True)
test.set_index('date_forecast', inplace=True)
train.index = pd.to_datetime(train.index)

# %%
import re
train = train.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
test = test.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))

# %%
train['pv_measurement'].isna().sum()
# Out:
# 808

# %%
train.columns
# Out:
# Index(['absolute_humidity_2mgm3', 'air_density_2mkgm3', 'ceiling_height_aglm',
#        'clear_sky_energy_1hJ', 'clear_sky_radW', 'cloud_base_aglm',
#        'dew_or_rimeidx', 'dew_point_2mK', 'diffuse_radW', 'diffuse_rad_1hJ',
#        'direct_radW', 'direct_rad_1hJ', 'effective_cloud_coverp', 'elevationm',
#        'fresh_snow_12hcm', 'fresh_snow_1hcm', 'fresh_snow_24hcm',
#        'fresh_snow_3hcm', 'fresh_snow_6hcm', 'is_dayidx', 'is_in_shadowidx',
#        'msl_pressurehPa', 'precip_5minmm', 'precip_type_5minidx',
#        'pressure_100mhPa', 'pressure_50mhPa', 'prob_rimep', 'rain_waterkgm2',
#        'relative_humidity_1000hPap', 'sfc_pressurehPa', 'snow_densitykgm3',
#        'snow_depthcm', 'snow_driftidx', 'snow_melt_10minmm', 'snow_waterkgm2',
#        'sun_azimuthd', 'sun_elevationd', 'super_cooled_liquid_waterkgm2',
#        't_1000hPaK', 'total_cloud_coverp', 'visibilitym', 'wind_speed_10mms',
#        'wind_speed_u_10mms', 'wind_speed_v_10mms', 'wind_speed_w_1000hPams',
#        'minute', 'hour', 'month', 'pv_measurement'],
#       dtype='object')

# %%
train.shape, test.shape
# Out:
# ((33652, 49), (1536, 48))

# %%
import pandas as pd

# Esempio di un DataFrame con una colonna rappresentante una curva
data = {'Tempo': [1, 2, 3, 4, 5, 6, 7, 8],
        'Curva': [1, 2, 2, 2, 3, 3, 2, 2]}

df = train

# Sostituisci 'colonna_curva' con il nome della colonna che rappresenta la curva
nome_colonna_curva = 'pv_measurement'

# Calcola la differenza tra i valori adiacenti
df['Differenza'] = df[nome_colonna_curva].diff()

# Filtra le righe in cui la differenza è diversa da zero
df_senza_stazionari = df[df['Differenza'] != 0]

# Ora df_senza_stazionari conterrà solo le righe in cui la curva non è stazionaria
# Puoi rimuovere la colonna 'Differenza' se non è più necessaria
df_senza_stazionari = df_senza_stazionari.drop(columns=['Differenza'])
df_senza_stazionari = df_senza_stazionari.reset_index()

# %%
df_senza_stazionari['pv_measurement'].dropna()
# Out:
# 0          0.000000
# 1          0.862500
# 2         10.350000
# 3          5.175000
# 4          0.862500
#             ...
# 14222    197.669857
# 14223    118.454331
# 14224     45.263035
# 14225      0.828587
# 14226     -0.000000
# Name: pv_measurement, Length: 13419, dtype: float64

# %%
df_senza_stazionari['pv_measurement'][12215:12890].plot()
# Out:
# <Axes: >

# %%
df_senza_stazionari.drop(range(12215, 12891), inplace=True)

# %%
train = df_senza_stazionari

# %%
train['pv_measurement'].plot()
# Out:
# <Axes: >

# %%
nan_col = ['snow_densitykgm3','ceiling_height_aglm','cloud_base_aglm']
for col in nan_col:
    
    test[col] = test[col].fillna(0)
    train[col] = train[col].fillna(train[col].median())

train=train.dropna()
test=test.dropna()
# Out:
# C:\Users\claxl\AppData\Local\Temp\ipykernel_87676\1027578152.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[col] = train[col].fillna(train[col].median())

# %%
train.set_index('date_forecast', inplace=True)
train.index = pd.to_datetime(train.index)
train  = train.drop(columns = 'index')

# %%
for column in train.columns:
    plt.figure()
    train[column].plot(kind='hist', bins=10, title=column)
    plt.xlabel(column)
    plt.ylabel('Frequenza')
    plt.show()

# %%
for column in test.columns:
    plt.figure()
    test[column].plot(kind='hist', bins=10, title=column)
    plt.xlabel(column)
    plt.ylabel('Frequenza')
    plt.show()

# %%
def transform(df):
    for col in df.columns:
        if col == 'pv_measurement':
            df['pv_measurement'] = np.sqrt(df['pv_measurement'])
            continue
        new_col_name = col + "_sqrt"
        df[new_col_name] = np.sqrt(df[col])

    return df

# %%
train = transform(train)
test = transform(test)
# Out:
# C:\Users\claxl\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\claxl\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\claxl\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\claxl\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\claxl\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\claxl\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\claxl\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
train.shape,test.shape
# Out:
# ((13399, 97), (720, 96))

# %%
train_set = train.iloc[:-4418]
val_set = train.tail(4418)

# %%
from sklearn.metrics import mean_absolute_error
import lightgbm as lgb
def objective(trial):
    param = {
            'metric': 'mae', 
            'random_state': 42,
            'n_estimators': trial.suggest_int('n_estimators',10,1000),
            'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-3, 10.0),
            'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-3, 10.0),
            'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.3,0.4,0.5,0.6,0.7,0.8,0.9, 1.0]),
            'subsample': trial.suggest_categorical('subsample', [0.4,0.5,0.6,0.7,0.8,1.0]),
            'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4,1e-1),
            'max_depth': trial.suggest_int('max_depth', 1,50),
            'num_leaves' : trial.suggest_int('num_leaves', 1, 1000),
            'min_child_samples': trial.suggest_int('min_child_samples', 1, 300),
            'cat_smooth' : trial.suggest_int('min_data_per_groups', 1, 100),
            'verbosity': -1
        }
    model = lgb.LGBMRegressor(**param)

        # Extract target variable for training and testing data
    y_train = train_set['pv_measurement']
    y_val = val_set['pv_measurement']

        # Extract features for training and testing data
    X_train = train_set.drop(columns = 'pv_measurement')
    X_val = val_set.drop(columns = 'pv_measurement')
        
        # Train the XGBoost model
    model.fit(X_train, y_train,eval_set=[(X_val,y_val)])

        # Make predictions on the test data
    y_pred = model.predict(X_val)

        # Evaluate the model using Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_val, y_pred)
    return mae

# %%
import optuna
import warnings
warnings.filterwarnings("ignore")
from warnings import simplefilter
simplefilter("ignore", category=RuntimeWarning)
study = optuna.create_study(direction='minimize')
# Out:
# [I 2023-10-31 18:06:10,909] A new study created in memory with name: no-name-62b24b96-9cd6-4d5a-9de5-c4dc4231da20

# %%
study.optimize(objective, n_trials=50)
# Out:
# [I 2023-10-31 18:06:11,197] Trial 0 finished with value: 7.060774752535999 and parameters: {'n_estimators': 71, 'reg_alpha': 0.31262349394671496, 'reg_lambda': 0.1387131019800041, 'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.0010088638240997303, 'max_depth': 6, 'num_leaves': 679, 'min_child_samples': 238, 'min_data_per_groups': 68}. Best is trial 0 with value: 7.060774752535999.
# [I 2023-10-31 18:06:12,115] Trial 1 finished with value: 2.4620007693849564 and parameters: {'n_estimators': 403, 'reg_alpha': 0.018975595313414664, 'reg_lambda': 1.0548454783078052, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.005960301367890643, 'max_depth': 30, 'num_leaves': 955, 'min_child_samples': 287, 'min_data_per_groups': 81}. Best is trial 1 with value: 2.4620007693849564.
# [I 2023-10-31 18:06:13,097] Trial 2 finished with value: 2.195583457547372 and parameters: {'n_estimators': 449, 'reg_alpha': 0.02785339174048674, 'reg_lambda': 0.8871350319671635, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.013323528162839928, 'max_depth': 5, 'num_leaves': 607, 'min_child_samples': 116, 'min_data_per_groups': 34}. Best is trial 2 with value: 2.195583457547372.
# [I 2023-10-31 18:06:13,299] Trial 3 finished with value: 2.216129196066539 and parameters: {'n_estimators': 117, 'reg_alpha': 3.093584017756379, 'reg_lambda': 7.5996727485219955, 'colsample_bytree': 0.3, 'subsample': 0.5, 'learning_rate': 0.03620563698548485, 'max_depth': 5, 'num_leaves': 366, 'min_child_samples': 220, 'min_data_per_groups': 24}. Best is trial 2 with value: 2.195583457547372.
# [I 2023-10-31 18:06:14,287] Trial 4 finished with value: 2.271881619606018 and parameters: {'n_estimators': 675, 'reg_alpha': 7.513612055701911, 'reg_lambda': 2.775941609472085, 'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.0698097747182868, 'max_depth': 4, 'num_leaves': 840, 'min_child_samples': 81, 'min_data_per_groups': 85}. Best is trial 2 with value: 2.195583457547372.
# [I 2023-10-31 18:06:15,927] Trial 5 finished with value: 7.278678120647396 and parameters: {'n_estimators': 298, 'reg_alpha': 4.560248889686482, 'reg_lambda': 0.03848437223104442, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.00011639074742275192, 'max_depth': 8, 'num_leaves': 462, 'min_child_samples': 50, 'min_data_per_groups': 63}. Best is trial 2 with value: 2.195583457547372.
# [I 2023-10-31 18:06:16,860] Trial 6 finished with value: 2.2326877444101956 and parameters: {'n_estimators': 243, 'reg_alpha': 4.837831170636746, 'reg_lambda': 0.03968121065905723, 'colsample_bytree': 0.4, 'subsample': 0.8, 'learning_rate': 0.05598275567598851, 'max_depth': 12, 'num_leaves': 658, 'min_child_samples': 98, 'min_data_per_groups': 49}. Best is trial 2 with value: 2.195583457547372.
# [I 2023-10-31 18:06:17,023] Trial 7 finished with value: 7.253509518403831 and parameters: {'n_estimators': 58, 'reg_alpha': 1.528165257637393, 'reg_lambda': 0.017284273716401267, 'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.0007065435155778987, 'max_depth': 3, 'num_leaves': 788, 'min_child_samples': 171, 'min_data_per_groups': 87}. Best is trial 2 with value: 2.195583457547372.
# [I 2023-10-31 18:06:23,940] Trial 8 finished with value: 2.3157613571058 and parameters: {'n_estimators': 988, 'reg_alpha': 0.00497476824371847, 'reg_lambda': 0.002091627938883528, 'colsample_bytree': 0.9, 'subsample': 0.4, 'learning_rate': 0.08607272148278189, 'max_depth': 25, 'num_leaves': 799, 'min_child_samples': 60, 'min_data_per_groups': 61}. Best is trial 2 with value: 2.195583457547372.
# [I 2023-10-31 18:06:27,025] Trial 9 finished with value: 7.078113974714824 and parameters: {'n_estimators': 571, 'reg_alpha': 7.205259819931662, 'reg_lambda': 0.07695149794373919, 'colsample_bytree': 0.8, 'subsample': 0.5, 'learning_rate': 0.00012010364294921236, 'max_depth': 40, 'num_leaves': 447, 'min_child_samples': 76, 'min_data_per_groups': 98}. Best is trial 2 with value: 2.195583457547372.
# [I 2023-10-31 18:06:32,440] Trial 10 finished with value: 2.2182601473862196 and parameters: {'n_estimators': 770, 'reg_alpha': 0.001157375505592654, 'reg_lambda': 0.7589942781269742, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.011204220863660434, 'max_depth': 19, 'num_leaves': 44, 'min_child_samples': 3, 'min_data_per_groups': 4}. Best is trial 2 with value: 2.195583457547372.
# [I 2023-10-31 18:06:33,004] Trial 11 finished with value: 2.221579700999569 and parameters: {'n_estimators': 229, 'reg_alpha': 0.10230258295800773, 'reg_lambda': 6.109394295733804, 'colsample_bytree': 0.3, 'subsample': 0.6, 'learning_rate': 0.016928451429028983, 'max_depth': 16, 'num_leaves': 247, 'min_child_samples': 172, 'min_data_per_groups': 27}. Best is trial 2 with value: 2.195583457547372.
# [I 2023-10-31 18:06:34,896] Trial 12 finished with value: 2.220717916438411 and parameters: {'n_estimators': 475, 'reg_alpha': 0.3420932224867728, 'reg_lambda': 8.306985403181981, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.02540997479674934, 'max_depth': 46, 'num_leaves': 297, 'min_child_samples': 224, 'min_data_per_groups': 32}. Best is trial 2 with value: 2.195583457547372.
# [I 2023-10-31 18:06:35,027] Trial 13 finished with value: 5.570933913679646 and parameters: {'n_estimators': 21, 'reg_alpha': 0.030738382167327716, 'reg_lambda': 1.2257910656734439, 'colsample_bytree': 0.3, 'subsample': 0.5, 'learning_rate': 0.026183504758289095, 'max_depth': 1, 'num_leaves': 289, 'min_child_samples': 222, 'min_data_per_groups': 19}. Best is trial 2 with value: 2.195583457547372.
# [W 2023-10-31 18:06:35,072] Trial 14 failed with parameters: {'n_estimators': 359, 'reg_alpha': 0.8540586948855698, 'reg_lambda': 9.01888090117552, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.00701363874333231, 'max_depth': 23, 'num_leaves': 554, 'min_child_samples': 140} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "C:\Users\claxl\anaconda3\Lib\site-packages\optuna\study\_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\claxl\AppData\Local\Temp\ipykernel_87676\2403515749.py", line 16, in objective
#     'cat_smooth' : trial.suggest_int('min_data_per_groups', 1, 100),
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\claxl\anaconda3\Lib\site-packages\optuna\trial\_trial.py", line 321, in suggest_int
#     suggested_value = int(self._suggest(name, distribution))
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\claxl\anaconda3\Lib\site-packages\optuna\trial\_trial.py", line 630, in _suggest
#     param_value = self.study.sampler.sample_independent(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\claxl\anaconda3\Lib\site-packages\optuna\samplers\_tpe\sampler.py", line 423, in sample_independent
#     return self._sample(study, trial, {param_name: param_distribution})[param_name]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\claxl\anaconda3\Lib\site-packages\optuna\samplers\_tpe\sampler.py", line 477, in _sample
#     log_likelihoods_above = mpe_above.log_pdf(samples_below)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\claxl\anaconda3\Lib\site-packages\optuna\samplers\_tpe\parzen_estimator.py", line 92, in log_pdf
#     return self._mixture_distribution.log_pdf(transformed_samples)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\claxl\anaconda3\Lib\site-packages\optuna\samplers\_tpe\probability_distributions.py", line 104, in log_pdf
#     log_gauss_mass = _truncnorm._log_gauss_mass(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\claxl\anaconda3\Lib\site-packages\optuna\samplers\_tpe\_truncnorm.py", line 143, in _log_gauss_mass
#     out[case_left] = mass_case_left(a[case_left], b[case_left])
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\claxl\anaconda3\Lib\site-packages\optuna\samplers\_tpe\_truncnorm.py", line 122, in mass_case_left
#     return _log_diff(_log_ndtr(b), _log_ndtr(a))
#                                    ^^^^^^^^^^^^
#   File "C:\Users\claxl\anaconda3\Lib\site-packages\optuna\samplers\_tpe\_truncnorm.py", line 105, in _log_ndtr
#     return np.frompyfunc(_log_ndtr_single, 1, 1)(a).astype(float)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\claxl\anaconda3\Lib\site-packages\optuna\samplers\_tpe\_truncnorm.py", line 77, in _log_ndtr_single
#     @functools.lru_cache(1000)
#
# KeyboardInterrupt
# [W 2023-10-31 18:06:35,082] Trial 14 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 study.optimize(objective, n_trials=50)
#
# File ~\anaconda3\Lib\site-packages\optuna\study\study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[90], line 16, in objective(trial)
#       3 def objective(trial):
#       4     param = {
#       5             'metric': 'mae',
#       6             'random_state': 42,
#       7             'n_estimators': trial.suggest_int('n_estimators',10,1000),
#       8             'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-3, 10.0),
#       9             'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-3, 10.0),
#      10             'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.3,0.4,0.5,0.6,0.7,0.8,0.9, 1.0]),
#      11             'subsample': trial.suggest_categorical('subsample', [0.4,0.5,0.6,0.7,0.8,1.0]),
#      12             'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4,1e-1),
#      13             'max_depth': trial.suggest_int('max_depth', 1,50),
#      14             'num_leaves' : trial.suggest_int('num_leaves', 1, 1000),
#      15             'min_child_samples': trial.suggest_int('min_child_samples', 1, 300),
# ---> 16             'cat_smooth' : trial.suggest_int('min_data_per_groups', 1, 100),
#      17             'verbosity': -1
#      18         }
#      19     model = lgb.LGBMRegressor(**param)
#      21         # Extract target variable for training and testing data
#
# File ~\anaconda3\Lib\site-packages\optuna\trial\_trial.py:321, in Trial.suggest_int(self, name, low, high, step, log)
#     239 """Suggest a value for the integer parameter.
#     240
#     241 The value is sampled from the integers in :math:`[\\mathsf{low}, \\mathsf{high}]`.
#    (...)
#     317     :ref:`configurations` tutorial describes more details and flexible usages.
#     318 """
#     320 distribution = IntDistribution(low=low, high=high, log=log, step=step)
# --> 321 suggested_value = int(self._suggest(name, distribution))
#     322 self._check_distribution(name, distribution)
#     323 return suggested_value
#
# File ~\anaconda3\Lib\site-packages\optuna\trial\_trial.py:630, in Trial._suggest(self, name, distribution)
#     628 else:
#     629     study = pruners._filter_study(self.study, trial)
# --> 630     param_value = self.study.sampler.sample_independent(
#     631         study, trial, name, distribution
#     632     )
#     634 # `param_value` is validated here (invalid value like `np.nan` raises ValueError).
#     635 param_value_in_internal_repr = distribution.to_internal_repr(param_value)
#
# File ~\anaconda3\Lib\site-packages\optuna\samplers\_tpe\sampler.py:423, in TPESampler.sample_independent(self, study, trial, param_name, param_distribution)
#     413     if any(param_name in trial.params for trial in trials):
#     414         _logger.warning(
#     415             f"The parameter '{param_name}' in trial#{trial.number} is sampled "
#     416             "independently instead of being sampled by multivariate TPE sampler. "
#    (...)
#     420             "if this independent sampling is intended behavior."
#     421         )
# --> 423 return self._sample(study, trial, {param_name: param_distribution})[param_name]
#
# File ~\anaconda3\Lib\site-packages\optuna\samplers\_tpe\sampler.py:477, in TPESampler._sample(self, study, trial, search_space)
#     475 samples_below = mpe_below.sample(self._rng.rng, self._n_ei_candidates)
#     476 log_likelihoods_below = mpe_below.log_pdf(samples_below)
# --> 477 log_likelihoods_above = mpe_above.log_pdf(samples_below)
#     478 ret = TPESampler._compare(samples_below, log_likelihoods_below, log_likelihoods_above)
#     480 for param_name, dist in search_space.items():
#
# File ~\anaconda3\Lib\site-packages\optuna\samplers\_tpe\parzen_estimator.py:92, in _ParzenEstimator.log_pdf(self, samples_dict)
#      90 def log_pdf(self, samples_dict: Dict[str, np.ndarray]) -> np.ndarray:
#      91     transformed_samples = self._transform(samples_dict)
# ---> 92     return self._mixture_distribution.log_pdf(transformed_samples)
#
# File ~\anaconda3\Lib\site-packages\optuna\samplers\_tpe\probability_distributions.py:104, in _MixtureOfProductDistribution.log_pdf(self, x)
#     102 x_lower = np.maximum(xi - d.step / 2, lower_limit)
#     103 x_upper = np.minimum(xi + d.step / 2, upper_limit)
# --> 104 log_gauss_mass = _truncnorm._log_gauss_mass(
#     105     (x_lower[:, None] - d.mu[None, :]) / d.sigma[None, :],
#     106     (x_upper[:, None] - d.mu[None, :]) / d.sigma[None, :],
#     107 )
#     108 log_p_accept = _truncnorm._log_gauss_mass(
#     109     (d.low - d.step / 2 - d.mu[None, :]) / d.sigma[None, :],
#     110     (d.high + d.step / 2 - d.mu[None, :]) / d.sigma[None, :],
#     111 )
#     112 log_pdfs[:, :, i] = log_gauss_mass - log_p_accept
#
# File ~\anaconda3\Lib\site-packages\optuna\samplers\_tpe\_truncnorm.py:143, in _log_gauss_mass(a, b)
#     141 out = np.full_like(a, fill_value=np.nan, dtype=np.complex128)
#     142 if a[case_left].size:
# --> 143     out[case_left] = mass_case_left(a[case_left], b[case_left])
#     144 if a[case_right].size:
#     145     out[case_right] = mass_case_right(a[case_right], b[case_right])
#
# File ~\anaconda3\Lib\site-packages\optuna\samplers\_tpe\_truncnorm.py:122, in _log_gauss_mass.<locals>.mass_case_left(a, b)
#     121 def mass_case_left(a: np.ndarray, b: np.ndarray) -> np.ndarray:
# --> 122     return _log_diff(_log_ndtr(b), _log_ndtr(a))
#
# File ~\anaconda3\Lib\site-packages\optuna\samplers\_tpe\_truncnorm.py:105, in _log_ndtr(a)
#     104 def _log_ndtr(a: np.ndarray) -> np.ndarray:
# --> 105     return np.frompyfunc(_log_ndtr_single, 1, 1)(a).astype(float)
#
# File ~\anaconda3\Lib\site-packages\optuna\samplers\_tpe\_truncnorm.py:77, in _log_ndtr_single(a)
#      72 def _ndtr(a: np.ndarray) -> np.ndarray:
#      73     # todo(amylase): implement erfc in _erf.py and use it for big |a| inputs.
#      74     return 0.5 + 0.5 * erf(a / 2**0.5)
# ---> 77 @functools.lru_cache(1000)
#      78 def _log_ndtr_single(a: float) -> float:
#      79     if a > 6:
#      80         return -_ndtr_single(-a)
#
# KeyboardInterrupt:

# %%
trial = study.best_trial

print("  Value: {}".format(trial.value))
print(trial.params)
# Out:
#   Value: 2.195583457547372
# {'n_estimators': 449, 'reg_alpha': 0.02785339174048674, 'reg_lambda': 0.8871350319671635, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.013323528162839928, 'max_depth': 5, 'num_leaves': 607, 'min_child_samples': 116, 'min_data_per_groups': 34}

# %%
param = {'n_estimators': 449, 'reg_alpha': 0.02785339174048674, 'reg_lambda': 0.8871350319671635, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.013323528162839928, 'max_depth': 5, 'num_leaves': 607, 'min_child_samples': 116, 'min_data_per_groups': 34}

# %%
model_A = lgb.LGBMRegressor(**param)

# %%
X_train = train.drop(columns = 'pv_measurement')
y_train = train['pv_measurement']

# %%
model_A.fit(X_train,y_train)
y_pred_A = model_A.predict(test)
# Out:
# [LightGBM] [Warning] Unknown parameter: min_data_per_groups
# [LightGBM] [Warning] Unknown parameter: min_data_per_groups
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002010 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 13435
# [LightGBM] [Info] Number of data points in the train set: 13399, number of used features: 76
# [LightGBM] [Info] Start training from score 11.308784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: min_data_per_groups

# %%
plt.plot(range(len(y_pred_A)), y_pred_A**2, label='Predizione', color='red', linestyle='-')

# Aggiungi una legenda
plt.legend()

# Aggiungi etichette agli assi
plt.ylabel('Valori y')

# Titolo del grafico
plt.title('Grafico di Predizione')

# Mostra il grafico
plt.show()

# %%
df = pd.DataFrame({'Prediction':y_pred_A})

# %%
df['Prediction'] = df['Prediction'].mask(train['is_in_shadowidx'] == 1, 0)

# %%
df.to_csv('B1.csv')
