# %%
import pandas as pd
A = pd.read_csv('A.csv')
B = pd.read_csv('B.csv')
C = pd.read_csv('C.csv')

# %%
pred = pd.concat([A,B,C], ignore_index = True)

# %%
pred = pred.drop(columns = 'Unnamed: 0')

# %%
pred['id'] = range(2160)

# %%
pred = pred.set_index(pred['id'])
pred = pred.drop(columns = 'id', axis = 1)
pred
# Out:
#       Prediction
# id
# 0       1.629716
# 1       1.604504
# 2       1.574441
# 3       1.606194
# 4      50.405080
# ...          ...
# 2155    0.000000
# 2156    0.000000
# 2157    0.000000
# 2158    0.427743
# 2159    0.662481
#
# [2160 rows x 1 columns]

# %%
pred.to_csv('LgbFE1.csv')

# %%
pred[0:719].plot()
# Out:
# <Axes: xlabel='id'>

# %%
pred[720:1439].plot()
# Out:
# <Axes: xlabel='id'>

# %%
pred[1440:2159].plot()
# Out:
# <Axes: xlabel='id'>
