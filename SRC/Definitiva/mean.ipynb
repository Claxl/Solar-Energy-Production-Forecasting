# %%
import pandas as pd
df1 = pd.read_csv('catcatcatlgb.csv')
#df2 = pd.read_csv('catcatcatlgb1.csv')
df3 = pd.read_csv('catcatlgb.csv')

# %%
df6 = (df1  + df3)/2

# %%
df6.set_index('id', inplace=True)

# %%
df6.to_csv('mean.csv')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15, 5))

ax.plot(df2[0:720].index, df2['prediction'][0:720], label='df2')
ax.plot(df3[0:720].index, df3['prediction'][0:720], label='df3')
ax.plot(df6[0:720].index, df6['prediction'][0:720], label='df6')

ax.set_xlabel('id')
ax.set_ylabel('prediction')
ax.legend()

plt.show()
