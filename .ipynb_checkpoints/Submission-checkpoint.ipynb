# %%
import pandas as pd
A = pd.read_csv('A1.csv')
B = pd.read_csv('B1.csv')
C = pd.read_csv('C1.csv')

# %%
pred = pd.concat([A,B,C], ignore_index = True)

# %%
pred = pred.drop(columns = 'Unnamed: 0')

# %%
pred['id'] = range(2160)

# %%
pred = pred.set_index(pred['id'])
pred = pred.drop(columns = 'id', axis = 1)
pred
# Out:
#       Prediction
# id
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3      46.503019
# 4     257.919968
# ...          ...
# 2155   62.656734
# 2156   15.783285
# 2157    0.000000
# 2158    0.000000
# 2159    0.000000
#
# [2160 rows x 1 columns]

# %%
pred.to_csv('lgbscalesqrtbro.csv')

# %%
pred[0:719].plot()
# Out:
# <Axes: xlabel='id'>

# %%
pred[720:1439].plot()
# Out:
# <Axes: xlabel='id'>

# %%
pred[1440:2159].plot()
# Out:
# <Axes: xlabel='id'>
